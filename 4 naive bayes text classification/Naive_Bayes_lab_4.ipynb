# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# %%
data = pd.read_csv("/content/text_classification.csv", names=['message', 'label'])
data
# Out:
#                                  message label
# 0                   I love this sandwich   pos
# 1               this is an amazing place   pos
# 2     I feel very good about these beers   pos
# 3                   this is my best work   pos
# 4                   what an awesome view   pos
# 5          I do not like this restaurant   neg
# 6               I am tired of this stuff   neg
# 7                 I can't deal with this   neg
# 8                   he is my sworn enemy   neg
# 9                    my boss is horrible   neg
# 10              this is an awesome place   pos
# 11  I donot like the taste of this juice   neg
# 12                       I love to dance   pos
# 13     I am sick and tired of this place   neg
# 14                  what a great holiday   pos
# 15        that is a bad locality to stay   neg
# 16        we will have good fun tomorrow   pos
# 17      I went to my enemy's house today   neg

# %%
data['labelnum'] = data.label.map({'pos':1, 'neg':0})
X = data.message
Y = data.labelnum

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y)
print ("\n the total number of Training Data :", ytrain.shape)
print ("\n the total number of Test Data :", ytest.shape)
# Out:
#  the total number of Training Data : (13,)
#
#  the total number of Test Data : (5,)

# %%
cv = CountVectorizer()
xtrain_dtm = cv.fit_transform(xtrain)
xtest_dtm=cv.transform(xtest)
print('n The words or Tokens in the text documents In')
print(cv.get_feature_names_out())
df=pd.DataFrame(xtrain_dtm. toarray(), columns=cv.get_feature_names_out())
# print(cv.get_feature_names())
# df=pd.DataFrame(xtrain_dtm. toarray(), columns=cv.get_feature_names())
# Out:
# n The words or Tokens in the text documents In
# ['about' 'am' 'amazing' 'an' 'awesome' 'bad' 'beers' 'best' 'boss' 'dance'
#  'do' 'donot' 'enemy' 'feel' 'good' 'great' 'he' 'holiday' 'horrible' 'is'
#  'juice' 'like' 'locality' 'love' 'my' 'not' 'of' 'place' 'restaurant'
#  'sandwich' 'stay' 'stuff' 'sworn' 'taste' 'that' 'the' 'these' 'this'
#  'tired' 'to' 'very' 'view' 'what' 'work']

# %%
clf = MultinomialNB().fit(xtrain_dtm, ytrain)
predicted = clf.predict(xtest_dtm)

# %%
print('Accuracy of the classifier is :', metrics.accuracy_score(ytest, predicted))
print('Confusion Matrix :\n')
print(metrics.confusion_matrix(ytest, predicted))
print('The value of predection :', metrics.precision_score(ytest, predicted))
print('The values of recall :', metrics.recall_score(ytest, predicted))
# Out:
# Accuracy of the classifier is : 0.8
# Confusion Matrix :
#
# [[2 1]
#  [0 2]]
# The value of predection : 0.6666666666666666
# The values of recall : 1.0

# %% [markdown]
# ## Self

# %%
data
# Out:
#                                  message label  labelnum
# 0                   I love this sandwich   pos         1
# 1               this is an amazing place   pos         1
# 2     I feel very good about these beers   pos         1
# 3                   this is my best work   pos         1
# 4                   what an awesome view   pos         1
# 5          I do not like this restaurant   neg         0
# 6               I am tired of this stuff   neg         0
# 7                 I can't deal with this   neg         0
# 8                   he is my sworn enemy   neg         0
# 9                    my boss is horrible   neg         0
# 10              this is an awesome place   pos         1
# 11  I donot like the taste of this juice   neg         0
# 12                       I love to dance   pos         1
# 13     I am sick and tired of this place   neg         0
# 14                  what a great holiday   pos         1
# ...

# %%
def text_classification(data):
    clas = list(data['label'].drop_duplicates())
    words = {}
    vocab = []
    for i in clas:
        words[i]={}
    for i in range(len(data)):
        text = data.iloc[i]['message']
        text = text.lower()
        text = text.split()
        vocab+=text
        words[data.iloc[i]['label']].update({i+1: text})
    print(words)
    vocab = list(set(vocab))
    print(vocab)
    dataframes = {}
    for i in clas:
        headings = []
        rows = list(words[i].keys())
        for j in words[i].values():
            headings+=j
        headings = list(set(headings))
        headings.sort()
        df = pd.DataFrame(index = rows,  columns = headings).fillna(0)
        for j in words[i].keys():
            for k in words[i][j]:
                df.loc[j, k]+=1

        dataframes[i] = df
        n = len(data)
        P = {x: len(dataframes[x])/n for x in clas}
        # sum(dataframes['pos'].sum())
        prob = {x: {} for x in clas}
        for j in clas:
            for k in dataframes[j].keys():
                prob[j].update({k: (1+sum(dataframes[j][k]))/(n+len(vocab))})
        print(prob)


    return words, clas, dataframes

words, clas, dataframes = text_classification(data)
# Out:
# {'pos': {1: ['i', 'love', 'this', 'sandwich'], 2: ['this', 'is', 'an', 'amazing', 'place'], 3: ['i', 'feel', 'very', 'good', 'about', 'these', 'beers'], 4: ['this', 'is', 'my', 'best', 'work'], 5: ['what', 'an', 'awesome', 'view'], 11: ['this', 'is', 'an', 'awesome', 'place'], 13: ['i', 'love', 'to', 'dance'], 15: ['what', 'a', 'great', 'holiday'], 17: ['we', 'will', 'have', 'good', 'fun', 'tomorrow']}, 'neg': {6: ['i', 'do', 'not', 'like', 'this', 'restaurant'], 7: ['i', 'am', 'tired', 'of', 'this', 'stuff'], 8: ['i', "can't", 'deal', 'with', 'this'], 9: ['he', 'is', 'my', 'sworn', 'enemy'], 10: ['my', 'boss', 'is', 'horrible'], 12: ['i', 'donot', 'like', 'the', 'taste', 'of', 'this', 'juice'], 14: ['i', 'am', 'sick', 'and', 'tired', 'of', 'this', 'place'], 16: ['that', 'is', 'a', 'bad', 'locality', 'to', 'stay'], 18: ['i', 'went', 'to', 'my', "enemy's", 'house', 'today']}}
# ...

# %%
sum(dataframes['pos']['a'])
# Out:
# 1

# %%
def Probabilities(n, dataframes, clas, words):
    prob = {}
